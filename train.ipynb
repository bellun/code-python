# %% [markdown]
# <a href="https://colab.research.google.com/github/bellun/code-python/blob/dev/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#bibliotecas necessárias
import pandas as pd
from google import colab as cl

#import files from PC
file_upload= cl.files.upload()
# Out:
#      <input type="file" id="files-20594a19-317a-4801-983b-13c0b7fe3626" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-20594a19-317a-4801-983b-13c0b7fe3626">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#import files from Google Drive

df= pd.read_csv('train.csv')

df.head()

#select de linhas

#df['Delivery_person_Age'] = pd.to_numeric(df['Delivery_person_Age'], errors='coerce')
df['Delivery_person_Age'] = pd.to_numeric(df['Delivery_person_Age'],errors='coerce')

linhas_selecionadas= df['Delivery_person_Age']>35
df[linhas_selecionadas]

# %% [markdown]
# # Nova seção

# %% [markdown]
# | Ação                              | Comando                                                    |
# |-----------------------------------|------------------------------------------------------------|
# | Descobrir dimensões do DataFrame  | `df.shape`                                                 |
# | Mostrar primeiras X linhas        | `df.head(X)`                                               |
# | Mostrar últimas X linhas          | `df.tail(X)`                                               |
# | Tipos das colunas                 | `df.dtypes`                                                |
# | Valores únicos de uma coluna      | `df['COLUNA'].unique()`                                    |
# | Ordenar DataFrame por coluna      | `df.sort_values('COLUNA', ascending=True)`                 |
# | Somar valores de uma coluna       | `df['COLUNA'].sum()`                                       |
# | Média de valores de uma coluna    | `df['COLUNA'].mean()`                                      |
# | Converter tipos de colunas        | `df['COLUNA'].astype('NOVO TIPO')`                         |
# | Converter strings para datas      | `pd.to_datetime(df['COLUNA'], format='%d-%m-%Y')`          |

# %%
#remover espaços de strings

import pandas as pd

# Suponha que df já foi carregado com pd.read_csv ou similar
df_copy = df.copy()

df_copy=df_copy.reset_index(drop=True)
for count in range(len(df_copy)):
  df_copy['ID']= df_copy.loc[count,'ID'].strip()


df_copy.head(20)
# Out:
#         ID Delivery_person_ID  Delivery_person_Age Delivery_person_Ratings  \
# 0   0x4607    INDORES13DEL02                  37.0                     4.9
# 1   0x4607    BANGRES18DEL02                  34.0                     4.5
# 2   0x4607    BANGRES19DEL01                  23.0                     4.4
# 3   0x4607   COIMBRES13DEL02                  38.0                     4.7
# 4   0x4607    CHENRES12DEL01                  32.0                     4.6
# 5   0x4607     HYDRES09DEL03                  22.0                     4.8
# 6   0x4607  RANCHIRES15DEL01                  33.0                     4.7
# 7   0x4607     MYSRES15DEL02                  35.0                     4.6
# 8   0x4607     HYDRES05DEL02                  22.0                     4.8
# 9   0x4607     DEHRES17DEL01                  36.0                     4.2
# 10  0x4607     KOCRES16DEL01                  21.0                     4.7
# ...

# %%
# Excluir as linhas com a idade dos entregadores vazia
# ( Conceitos de seleção condicional )
df_copy = df.copy()

linhas_vazias = (df['Delivery_person_Age'] != 'NaN') | (df_copy['multiple_deliveries'] != 'NaN')
df_copy = df_copy.loc[linhas_vazias, :]
# Conversao de texto/categoria/string para numeros inteiros
#df_copy['Delivery_person_Age'] = df_copy['Delivery_person_Age'].astype( int )


#Conversao da coluna Rattings de str para float
df_copy['Delivery_person_Ratings'] = df_copy['Delivery_person_Ratings'].astype(float)

#converter order_date de str para data
df_copy['Order_Date'] = pd.to_datetime(df_copy['Order_Date'], format='%d-%m-%Y')

#Converter multiple_deliveries para bol
df_copy['multiple_deliveries'] = df_copy['multiple_deliveries'].astype('bool')

#remover espaços de strings
for count in range(len(df_copy)):
  df_copy['ID']= df_copy.loc[count,'ID'].strip()
# Out:
# ID                                     object
# Delivery_person_ID                     object
# Delivery_person_Age                   float64
# Delivery_person_Ratings               float64
# Restaurant_latitude                   float64
# Restaurant_longitude                  float64
# Delivery_location_latitude            float64
# Delivery_location_longitude           float64
# Order_Date                     datetime64[ns]
# Time_Orderd                            object
# Time_Order_picked                      object
# Weatherconditions                      object
# Road_traffic_density                   object
# Vehicle_condition                       int64
# Type_of_order                          object
# Type_of_vehicle                        object
# multiple_deliveries                      bool
# Festival                               object
# City                                   object
# Time_taken(min)                        object
# dtype: object

# %% [markdown]
# ```
# # Isto está formatado como código
#
# Conteúdo:
# As perguntas de negócio
# 1. Qual o número total de entregadores cadastrados na base de dados?
#
# 2. Qual o número total de entregadores únicos cadastrados na base de dados?
#
# 3. Qual a idade do entregador mais velho? E do mais novo?
#
# 4. Qual o ID do entregador com a maior idade? E o ID do entregaor com a
# menor idade?
#
# 5. Quais os nomes das condições climáticas?
#
# 6. Quantas entregas foram realizadas sob condições climáticas de tempestade
# de areia? ( Sandstorms )
#
# 7. Quais eram as condicões climáticas da data mais recente de entrega?
#
# 8. Quantos tipos de densidade de trânsito existem na base de dados? Quais os
# nomes delas?
#
# 9. Quantas entregas foram feitas em cada condição climática?
#
# 10. Quantos entregadores únicos fizeram entregas em cada condição climática?
#
# 11. Quantas entregas foram feitas em cada tipo de densidade de trânsito?
#
# 12. Quantos entregadores únicos fizeram entregas em cada tipo de densidade
#
# de trânsito?
#
# 13. Quantas cidades únicas existem na base? Quais são os seus nomes?
#
# 14. Quantos tipos de veículos únicos existem na base?
#
# 15. Qual o tipo de veículo que mais vez entregas com a condição de trânsito
# pesado? ( High )
#
# 16. Qual o tipo de pedido mais feito durante condições climáticas de tempestade
# de areia?
#
# 17. Qual a cidade com o maior número de pedidos de Bebidas (Drinks) feito em
# Scooter?
#
# 18. Qual o nome da cidade com o (os) entregador mais velho? E o nome da
# cidade com o (os) entregadores mais novos?
#
# 19. Quantas entregas foram feitas durante o Festival?
#
# 20. Quantas cidades únicas tiveram entregas feitas durante o Festival?
#
#
# 21. Quantas entregas foram feitas durante o Festival na cidade chamada Urban
# ("Urban")
# ```

# %%
import pandas as pd
from google.colab import drive


# Montar o Google Drive
drive.mount('/content/drive')

# Definir o caminho do arquivo dentro do Google Drive
filepath = '/content/drive/MyDrive/Colab Notebooks/meigarom_ds/train.csv'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#As perguntas de negócio
#1. Qual o número total de entregadores cadastrados na base de dados?
# SA=> Mostrar um número com total de entregadores cadastrados na base de dados
# P=>selecionar todas as linhas da coluna que identifica os entregadores e fazer um somatório e guardar em uma variável para apresentar posteriormente
# E=> código
#bibliotecas necessárias
from IPython.display import display


# Carregar o arquivo CSV no DataFrame
df = pd.read_csv(filepath)

# Fazer uma cópia do DataFrame
data_frame_aux = df.copy()

# Exibindo a última linha do DataFrame
display(data_frame_aux.tail())

# Usar display para exibir a forma do DataFrame

display(data_frame_aux.shape)


qtde_entregadores = data_frame_aux['Delivery_person_ID'].count()
print(format((qtde_entregadores)))
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 45588  0x7c09      JAPRES04DEL01                   30                     4.8
# 45589  0xd641      AGRRES16DEL01                   21                     4.6
# 45590  0x4f8d     CHENRES08DEL03                   30                     4.9
# 45591  0x5eee    COIMBRES11DEL01                   20                     4.7
# 45592  0x5fb2   RANCHIRES09DEL02                   23                     4.9
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 45588            26.902328             75.794257                   26.912328
# 45589             0.000000              0.000000                    0.070000
# 45590            13.022394             80.242439                   13.052394
# 45591            11.001753             76.986241                   11.041753
# 45592            23.351058             85.325731                   23.431058
#
# ...

# %%
#2. Qual o número total de entregadores únicos cadastrados na base de dados?


data_frame_aux['Delivery_person_ID'].nunique()
# Out:
# 1320

# %%
#3. Qual a idade do entregador mais velho? E do mais novo?

data_frame_aux = data_frame_aux[data_frame_aux['Delivery_person_Age'].notna()]

#data_frame_aux['Delivery_person_Age'].min()

data_frame_aux['Delivery_person_Age'] = pd.to_numeric(data_frame_aux['Delivery_person_Age'], errors='coerce')
print("Maior Idade: "+ str(data_frame_aux['Delivery_person_Age'].dropna().max()))
print("Menor Idade: "+ str(data_frame_aux['Delivery_person_Age'].dropna().min()))
# Out:
# Maior Idade: 50.0
# Menor Idade: 15.0
